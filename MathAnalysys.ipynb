# %% [raw]
# The problem to be investigated is which factor influences the math test score the most.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\SQL\Analiza_Oceny_Matematyka\BazaDanych\student_math_cleanc.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             395 non-null    int64
#  1   school                 395 non-null    object
#  2   sex                    395 non-null    object
#  3   age                    395 non-null    int64
#  4   address_type           395 non-null    object
#  5   family_size            395 non-null    object
#  6   parent_status          395 non-null    object
#  7   mother_education       395 non-null    object
#  8   father_education       395 non-null    object
#  9   mother_job             395 non-null    object
#  10  father_job             395 non-null    object
#  11  school_choice_reason   395 non-null    object
#  12  guardian               395 non-null    object
#  13  travel_time            395 non-null    object
# ...

# %%
data.head()
# Out:
#    student_id school sex  age address_type              family_size  \
# 0           1     GP   F   18        Urban           Greater than 3
# 1           2     GP   F   17        Urban           Greater than 3
# 2           3     GP   F   15        Urban  Less than or equal to 3
# 3           4     GP   F   15        Urban           Greater than 3
# 4           5     GP   F   16        Urban           Greater than 3
#
#      parent_status               mother_education  \
# 0            Apart               higher education
# 1  Living together  primary education (4th grade)
# 2  Living together  primary education (4th grade)
# 3  Living together               higher education
# 4  Living together            secondary education
#
#                 father_education mother_job  ... family_relationship  \
# 0               higher education    at_home  ...                   4
# 1  primary education (4th grade)    at_home  ...                   5
# ...

# %%
data.describe()
# Out:
#        student_id         age  class_failures  family_relationship  \
# count  395.000000  395.000000      395.000000           395.000000
# mean   198.000000   16.696203        0.334177             3.944304
# std    114.170924    1.276043        0.743651             0.896659
# min      1.000000   15.000000        0.000000             1.000000
# 25%     99.500000   16.000000        0.000000             4.000000
# 50%    198.000000   17.000000        0.000000             4.000000
# 75%    296.500000   18.000000        0.000000             5.000000
# max    395.000000   22.000000        3.000000             5.000000
#
#         free_time      social  weekday_alcohol  weekend_alcohol      health  \
# count  395.000000  395.000000       395.000000       395.000000  395.000000
# mean     3.235443    3.108861         1.481013         2.291139    3.554430
# std      0.998862    1.113278         0.890741         1.287897    1.390303
# ...

# %%
print(data)
# Out:
#      student_id school sex  age address_type              family_size  \
# 0             1     GP   F   18        Urban           Greater than 3
# 1             2     GP   F   17        Urban           Greater than 3
# 2             3     GP   F   15        Urban  Less than or equal to 3
# 3             4     GP   F   15        Urban           Greater than 3
# 4             5     GP   F   16        Urban           Greater than 3
# ..          ...    ...  ..  ...          ...                      ...
# 390         391     MS   M   20        Urban  Less than or equal to 3
# 391         392     MS   M   17        Urban  Less than or equal to 3
# 392         393     MS   M   21        Rural           Greater than 3
# 393         394     MS   M   18        Rural  Less than or equal to 3
# 394         395     MS   M   19        Urban  Less than or equal to 3
#
#        parent_status               mother_education  \
# 0              Apart               higher education
# ...

# %%
sns.barplot(data = data, x = 'school', y = 'final_grade')
# Out:
# <Axes: xlabel='school', ylabel='final_grade'>

# %%
sns.barplot(data = data, x = 'parent_status', y ='final_grade')
# Out:
# <Axes: xlabel='parent_status', ylabel='final_grade'>

# %%
sns.barplot(data = data, x = 'address_type', y ='final_grade')
# Out:
# <Axes: xlabel='address_type', ylabel='final_grade'>

# %%
sns.barplot(data = data, x = 'family_size', y ='final_grade')
# Out:
# <Axes: xlabel='family_size', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'mother_education', y ='final_grade')
# Out:
# <Axes: xlabel='mother_education', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'father_education', y ='final_grade')
# Out:
# <Axes: xlabel='father_education', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'mother_job', y ='final_grade')
# Out:
# <Axes: xlabel='mother_job', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'father_job', y ='final_grade')
# Out:
# <Axes: xlabel='father_job', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'family_support', y ='final_grade')
# Out:
# <Axes: xlabel='family_support', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'extra_paid_classes', y ='final_grade')
# Out:
# <Axes: xlabel='extra_paid_classes', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'activities', y ='final_grade')
# Out:
# <Axes: xlabel='activities', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'higher_ed', y ='final_grade')
# Out:
# <Axes: xlabel='higher_ed', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'internet_access', y ='final_grade')
# Out:
# <Axes: xlabel='internet_access', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'romantic_relationship', y ='final_grade')
# Out:
# <Axes: xlabel='romantic_relationship', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'travel_time', y ='final_grade')
# Out:
# <Axes: xlabel='travel_time', ylabel='final_grade'>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data = data, x = 'study_time', y ='final_grade')
# Out:
# <Axes: xlabel='study_time', ylabel='final_grade'>

# %%
sns.scatterplot(data = data, x='free_time', y='final_grade', hue = 'social')
# Out:
# <Axes: xlabel='free_time', ylabel='final_grade'>

# %%
sns.regplot( data = data, y='final_grade', x = 'family_relationship')
# Out:
# <Axes: xlabel='family_relationship', ylabel='final_grade'>

# %%
sns.regplot( data = data, y='final_grade', x= 'class_failures')
# Out:
# <Axes: xlabel='class_failures', ylabel='final_grade'>

# %%
sns.regplot( data = data, y='final_grade', x= 'weekday_alcohol')
# Out:
# <Axes: xlabel='weekday_alcohol', ylabel='final_grade'>

# %%
sns.regplot( data = data, y='final_grade', x= 'weekend_alcohol')
# Out:
# <Axes: xlabel='weekend_alcohol', ylabel='final_grade'>

# %% [raw]
# The factors that influence the grade in mathematics are place of residence, access to the Internet and motivation to undertake higher education.
